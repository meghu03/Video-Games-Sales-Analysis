# %%
#importing necessary libraries
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
sheet_name = 'videogames_sales'
sheet_id = '1t6kVv95bVRQ9NyC1h3pO06WH8tREZDGq'
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

# %%
#Loading the dataset
data = pd.read_csv(url)
data
# Out:
#                           Name Platform    Year         Genre  \
# 0                   Wii Sports      Wii  2006.0        Sports
# 1            Super Mario Bros.      NES  1985.0      Platform
# 2               Mario Kart Wii      Wii  2008.0        Racing
# 3            Wii Sports Resort      Wii  2009.0        Sports
# 4     Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# ...                        ...      ...     ...           ...
# 4994            Disney Sing It      PS3  2008.0          Misc
# 4995       Peppa Pig: The Game      Wii  2009.0          Misc
# 4996   God Eater 2: Rage Burst      PSV  2015.0  Role-Playing
# 4997        Get Fit with Mel B      PS3  2010.0        Sports
# 4998        The Cat in the Hat      GBA  2005.0      Platform
#
#                        Publisher  NorthAmerica_Sales  Europe_Sales  \
# 0                       Nintendo               41.49         29.02
# 1                       Nintendo               29.08          3.58
# ...

# %%
#Removing rows containing null values
df = pd.DataFrame(data)
df.dropna(inplace=True)
df
# Out:
#                           Name Platform    Year         Genre  \
# 0                   Wii Sports      Wii  2006.0        Sports
# 1            Super Mario Bros.      NES  1985.0      Platform
# 2               Mario Kart Wii      Wii  2008.0        Racing
# 3            Wii Sports Resort      Wii  2009.0        Sports
# 4     Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# ...                        ...      ...     ...           ...
# 4994            Disney Sing It      PS3  2008.0          Misc
# 4995       Peppa Pig: The Game      Wii  2009.0          Misc
# 4996   God Eater 2: Rage Burst      PSV  2015.0  Role-Playing
# 4997        Get Fit with Mel B      PS3  2010.0        Sports
# 4998        The Cat in the Hat      GBA  2005.0      Platform
#
#                        Publisher  NorthAmerica_Sales  Europe_Sales  \
# 0                       Nintendo               41.49         29.02
# 1                       Nintendo               29.08          3.58
# ...

# %%
#Checking for duplicates
df = df.drop_duplicates()
df.duplicated().values.any()
# Out:
# False

# %%
#Checking for Null values 
pd.isnull(df).any()
# Out:
# Name                  False
# Platform              False
# Year                  False
# Genre                 False
# Publisher             False
# NorthAmerica_Sales    False
# Europe_Sales          False
# Japan_Sales           False
# Other_Sales           False
# Global_Sales          False
# dtype: bool

# %%
#Renaming the columns
data = data.rename(columns={'Name':'Games Name','Platform':'Platforms'})
data
# Out:
#                     Games Name Platforms    Year         Genre  \
# 0                   Wii Sports       Wii  2006.0        Sports
# 1            Super Mario Bros.       NES  1985.0      Platform
# 2               Mario Kart Wii       Wii  2008.0        Racing
# 3            Wii Sports Resort       Wii  2009.0        Sports
# 4     Pokemon Red/Pokemon Blue        GB  1996.0  Role-Playing
# ...                        ...       ...     ...           ...
# 4994            Disney Sing It       PS3  2008.0          Misc
# 4995       Peppa Pig: The Game       Wii  2009.0          Misc
# 4996   God Eater 2: Rage Burst       PSV  2015.0  Role-Playing
# 4997        Get Fit with Mel B       PS3  2010.0        Sports
# 4998        The Cat in the Hat       GBA  2005.0      Platform
#
#                        Publisher  NorthAmerica_Sales  Europe_Sales  \
# 0                       Nintendo               41.49         29.02
# 1                       Nintendo               29.08          3.58
# ...

# %%
#Dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4923 entries, 0 to 4998
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                4923 non-null   object
#  1   Platform            4923 non-null   object
#  2   Year                4923 non-null   float64
#  3   Genre               4923 non-null   object
#  4   Publisher           4923 non-null   object
#  5   NorthAmerica_Sales  4923 non-null   float64
#  6   Europe_Sales        4923 non-null   float64
#  7   Japan_Sales         4923 non-null   float64
#  8   Other_Sales         4923 non-null   float64
#  9   Global_Sales        4923 non-null   float64
# dtypes: float64(6), object(4)
# memory usage: 423.1+ KB

# %%
#Looking into the first 5 rows of the dataset
df.head()
# Out:
#                        Name Platform    Year         Genre Publisher  \
# 0                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NorthAmerica_Sales  Europe_Sales  Japan_Sales  Other_Sales  Global_Sales
# 0               41.49         29.02         3.77         8.46         82.74
# 1               29.08          3.58         6.81         0.77         40.24
# 2               15.85         12.88         3.79         3.31         35.82
# 3               15.75         11.01         3.28         2.96         33.00
# 4               11.27          8.89        10.22         1.00         31.37

# %%
#Looking into the last 5 rows of the dataset
df.tail()
# Out:
#                          Name Platform    Year         Genre  \
# 4994           Disney Sing It      PS3  2008.0          Misc
# 4995      Peppa Pig: The Game      Wii  2009.0          Misc
# 4996  God Eater 2: Rage Burst      PSV  2015.0  Role-Playing
# 4997       Get Fit with Mel B      PS3  2010.0        Sports
# 4998       The Cat in the Hat      GBA  2005.0      Platform
#
#                        Publisher  NorthAmerica_Sales  Europe_Sales  \
# 4994  Disney Interactive Studios                0.27          0.07
# 4995                    Pinnacle                0.00          0.35
# 4996          Namco Bandai Games                0.00          0.01
# 4997            Black Bean Games                0.15          0.17
# 4998           Jack of All Games                0.27          0.10
#
#       Japan_Sales  Other_Sales  Global_Sales
# 4994         0.00         0.04          0.38
# 4995         0.00         0.03          0.38
# 4996         0.37         0.00          0.38
# ...

# %%
print(f'Number of rows : {len(df.axes[0])}')
print(f'Number of columns : {len(df.axes[1])}')
# Out:
# Number of rows : 4923
# Number of columns : 10

# %%
#To calculate statistical data
df.describe()
# Out:
#               Year  NorthAmerica_Sales  Europe_Sales  Japan_Sales  \
# count  4923.000000         4923.000000   4923.000000  4923.000000
# mean   2005.353240            0.739218      0.428862     0.195184
# std       6.638465            1.380354      0.861139     0.541931
# min    1980.000000            0.000000      0.000000     0.000000
# 25%    2002.000000            0.240000      0.090000     0.000000
# 50%    2007.000000            0.420000      0.220000     0.000000
# 75%    2010.000000            0.780000      0.460000     0.130000
# max    2016.000000           41.490000     29.020000    10.220000
#
#        Other_Sales  Global_Sales
# count  4923.000000   4923.000000
# mean      0.140335      1.503614
# std       0.327078      2.603735
# min       0.000000      0.380000
# 25%       0.030000      0.540000
# 50%       0.070000      0.830000
# 75%       0.140000      1.510000
# max      10.570000     82.740000

# %%
import pandas as pd
from matplotlib import pyplot as plt
data = df
data.head()
df = pd.DataFrame(data)
plt.figure(figsize = (10,10))
plt.bar(df["Year"].value_counts().index, df["Year"].value_counts())
plt.xlabel("Years")
plt.ylabel("Count of games")
plt.title("Number of releases of video games for Years")
plt.show()

# %%
#To find average NorthAmerica_Sales
avg_sales = df["NorthAmerica_Sales"].mean()
avg_sales
# Out:
# 0.7392179565305708

# %%
#To find average Europe_Sales
avg_sales = df["Europe_Sales"].mean()
avg_sales
# Out:
# 0.42886248222628476

# %%
#To find average Japan_Sales
avg_sales = df["Japan_Sales"].mean()
avg_sales
# Out:
# 0.1951838309973593

# %%
#relational plot between Genre and NorthAmerica_Sales
sns.relplot(
    data=df, 
    x="Genre", y="NorthAmerica_Sales", 
    kind="line",
    height=5, aspect=2
)

# %%
#relational plot between Genre and Europe_Sales
sns.relplot(
    data=df, 
    x="Genre", y="Europe_Sales", 
    kind="line",
    height=5, aspect=2
)

# %%
#relational plot between Genre and Japan_Sales
sns.relplot(
    data=df, 
    x="Genre", y="Japan_Sales", 
    kind="line",
    height=5, aspect=2
)

# %%
#relational plot between Genre and Other_Sales
sns.relplot(
    data=df, 
    x="Genre", y="Other_Sales", 
    kind="line",
    height=5, aspect=2
)

# %%
plt.figure(figsize = (20,10))
plt.bar(df["Platform"].value_counts().index, df["Platform"].value_counts())
plt.title("Most Games produced in Specific Gaming Platform")
plt.show()
